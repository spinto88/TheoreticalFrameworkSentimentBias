# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt  
from scipy.optimize import minimize, Bounds
from functools import partial
from scipy.stats import spearmanr
import json 

np.random.seed(123453)

# %% [markdown]
# ### Data

# %%
data = pd.read_csv('Data/data2024.csv')
data
# Out:
#                  page_name  num_posts  Trump_positive  Trump_negative  \
# 0      ConservativeNewsDly       3020              33             154
# 1                  NEWSMAX       2860             114             398
# 2       WashingtonExaminer       2439              26             228
# 3            NewsNationNow       1877               8             177
# 4                Breitbart       1552             106             198
# 5                  TheHill       1358               5             167
# 6                  nytimes       1194               4             314
# 7                  ABCNews       1007               2             118
# 8                  FoxNews        966              18              73
# 9                  NBCNews        932               4             235
# 10             NBCPolitics        898               5             174
# 11             DailyCaller        890              16              49
# 12              WSJOpinion        855              11              87
# 13                 CBSNews        849               3             138
# 14          washingtonpost        835               0             212
# 15              BlazeMedia        824              22              79
# 16           thedailybeast        799               5             250
# 17              politifact        750               0             125
# 18                Newsweek        741               8             163
# 19      TheWashingtonTimes        736              15             154
# 20             cnnpolitics        714               5             180
# 21                TheBlaze        709              21              66
# 22             newsbusters        702               3             104
# 23                newshour        700               2              98
# 24                     TND        690               6              71
# 25                mediaite        679               1              70
# 26       bloombergbusiness        676               7             130
# 27          WesternJournal        663              12              44
# 28            RedStateBlog        657               9              39
# 29        HuffPostPolitics        653               3             216
# 30                  snopes        629              13              95
# 31       blazenewsofficial        623              17              51
# 32                  forbes        617               6             170
# 33  theconservativetribune        598              17              28
# 34                     cnn        591               4             159
# 35                  theijr        588              22              94
# 36     mediaresearchcenter        575               6              93
# 37            ABC7Amarillo        574               7              88
# 38           nowthisimpact        571               0             134
# 39                politico        560               1             105
#
#     Trump_neutral  Kamala_positive  Kamala_negative  Kamala_neutral  \
# 0             399               20              167             152
# 1             440               36              379             202
# 2             247               47              234             179
# 3             342               47               40             240
# 4             112                8              455              32
# 5              41               65               50              87
# 6              98               78               31             154
# 7              75               77               34             178
# 8              43               22              188              74
# 9              99               39               33             103
# 10             81               47               31             110
# 11             23               24              253              49
# 12             53               11              276              39
# 13            121               52               14              97
# 14             93               45               25             103
# 15             36                6              226              23
# 16             40               35               70              59
# 17             56                1               50             130
# 18             68               49               50              83
# 19            115               19               73              66
# 20            105               33               23              98
# 21             28                8              180              19
# 22              8               16              218              17
# 23            116               33                3             103
# 24            107               17               35              92
# 25             21               14               78              60
# 26            106               48               35              83
# 27             49                6              202              42
# 28              9                9              280              22
# 29             34               34               53              46
# 30             40               18               69             114
# 31             24                8              165              17
# 32            121               14               18              43
# 33             21                3              237              25
# 34             80               25               19              76
# 35             73                8              131              45
# 36             11               14              174              20
# 37            109               20               55              88
# 38              2              124               20              36
# 39             54               30               25              68
#
#     Vance_positive  Vance_negative  ...  Walz_negative  Walz_neutral  \
# 0                0               2  ...             20             8
# 1                8               7  ...             67            24
# 2                1              10  ...             59            17
# 3                3              12  ...              7            23
# 4                6               9  ...             33             2
# 5                7              35  ...             13            34
# 6                0               9  ...              3            18
# 7                2               6  ...              2            24
# 8                6              17  ...             62            10
# 9                0              20  ...              4            13
# 10               0              18  ...              4            19
# 11              19              33  ...             84            14
# 12               0               5  ...             25             4
# 13               0               9  ...              2            27
# 14               0              16  ...              8            15
# 15              15              19  ...             54             3
# 16               1              32  ...             15            10
# 17               0              16  ...             11            40
# 18               1              10  ...              3            13
# 19               0               0  ...             15             6
# 20               0              11  ...              3            11
# 21              11              16  ...             36             6
# 22              10              27  ...             68             6
# 23               0               3  ...              3            15
# 24               1               9  ...             20             9
# 25               5              38  ...             22             1
# 26               0               3  ...              2             5
# 27               0               6  ...             39            10
# 28              13              26  ...             73             4
# 29               0              14  ...              0             9
# 30               0              31  ...             71            60
# 31              14              19  ...             44             2
# 32               0               4  ...              2             2
# 33               2               2  ...             37             6
# 34               0               8  ...              3            11
# 35               1               0  ...             18             5
# 36              10              22  ...             59             5
# 37               1               2  ...             10            12
# 38               0              21  ...             12             4
# 39               1               7  ...              1            11
#
#                  media_type     media_bias bias_value factual_reporting  \
# 0                   website  extreme right        NaN             mixed
# 1                TV station          right        7.8               low
# 2                  magazine   right-center        3.8    mostly factual
# 3                TV station   least biased        1.2              high
# 4                   website          right        8.1             mixed
# 5                 newspaper   least biased        0.4    mostly factual
# 6                 newspaper    left-center       -4.1              high
# 7                TV station    left-center       -3.3              high
# 8        TV station/website          right        6.7             mixed
# 9                TV station    left-center       -3.6              high
# 10               TV station    left-center       -3.6              high
# 11                  website          right        6.6             mixed
# 12                newspaper   right-center        4.2    mostly factual
# 13               TV station    left-center       -3.3              high
# 14                newspaper    left-center       -3.6    mostly factual
# 15               TV station          right        7.8             mixed
# 16                  website           left       -6.6             mixed
# 17                  website    left-center       -3.1              high
# 18                 magazine   right-center        2.8    mostly factual
# 19                newspaper   right-center        4.2             mixed
# 20       TV station/website    left-center       -3.6    mostly factual
# 21               TV station          right        7.8             mixed
# 22  organization/foundation          right        NaN             mixed
# 23               TV station    left-center       -2.4              high
# 24       TV station/website   right-center        2.4              high
# 25                  website    left-center       -4.5              high
# 26               TV station    left-center       -2.4    mostly factual
# 27                  website      far right        8.0             mixed
# 28                  website          right        NaN             mixed
# 29                  website           left       -6.4             mixed
# 30                  website    left-center       -2.8              high
# 31               TV station          right        7.8             mixed
# 32                 magazine   least biased        1.3    mostly factual
# 33                  website  extreme right        NaN          very low
# 34       TV station/website    left-center       -3.6    mostly factual
# 35                  website          right        6.7    mostly factual
# 36  organization/foundation          right        7.1             mixed
# 37               TV statopm   right-center        2.5              high
# 38                  website       far left       -8.5             mixed
# 39                  website    left-center       -2.8              high
#
#     factual_value                                            comment  country  \
# 0             NaN                                                NaN      USA
# 1             7.6                                                NaN      USA
# 2             2.2                                                NaN      USA
# 3             1.1                                                NaN      USA
# 4             6.4                                                NaN      USA
# 5             2.2                                                NaN      USA
# 6             1.4                                                NaN      USA
# 7             1.1                                                NaN      USA
# 8             6.1                                                NaN      USA
# 9             1.0                                                NaN      USA
# 10            1.0           politics branch of NBC News (just below)      USA
# 11            5.5                                                NaN      USA
# 12            2.4  opinion branch of Wall Street Journal. I used ...      USA
# 13            1.0                                                NaN      USA
# 14            2.1                                                NaN      USA
# 15            6.3                        owner of The Blaze (row 34)      USA
# 16            4.8                                                NaN      USA
# 17            1.0                                                NaN      USA
# 18            2.6                                                NaN      USA
# 19            6.4                                                NaN      USA
# 20            3.7                    politics branch of CNN (row 39)      USA
# 21            6.3                                                NaN      USA
# 22            NaN                                                NaN      USA
# 23            1.0                                                NaN      USA
# 24            1.2                                                NaN      USA
# 25            1.6                                                NaN      USA
# 26            2.2                                                NaN      USA
# 27            6.3                                                NaN      USA
# 28            NaN                                                NaN      USA
# 29            4.6  politics branch of HuffPost (or Huffington Pos...      USA
# 30            1.2                                                NaN      USA
# 31            6.3                                Data from The Blaze      USA
# 32            2.0                                                NaN      USA
# 33            NaN                                                NaN      USA
# 34            3.7                                                NaN      USA
# 35            2.9                                                NaN      USA
# 36            6.3                                                NaN      USA
# 37            1.0                                                NaN      USA
# 38            6.2                                                NaN      USA
# 39            1.3                                                NaN      USA
#
#    sentiment_bias
# 0        0.043750
# 1        0.072557
# 2        0.025496
# 3       -0.196371
# 4        0.396285
# 5       -0.381308
# 6       -0.515110
# 7       -0.320826
# 8        0.293006
# 9       -0.455806
# 10      -0.401942
# 11       0.447140
# 12       0.401942
# 13      -0.392857
# 14      -0.466165
# 15       0.437113
# 16      -0.445076
# 17      -0.194444
# 18      -0.356674
# 19      -0.159915
# 20      -0.411017
# 21       0.397468
# 22       0.307054
# 23      -0.341085
# 24      -0.103896
# 25      -0.055728
# 26      -0.335681
# 27       0.463007
# 28       0.613963
# 29      -0.508393
# 30       0.005597
# 31       0.444751
# 32      -0.425197
# 33       0.665803
# 34      -0.430412
# 35       0.175439
# 36       0.282297
# 37      -0.097257
# 38      -0.720627
# 39      -0.388535
#
# [40 rows x 22 columns]

# %%
data["num_posts"].sum()
# Out:
# 38151

# %% [markdown]
# Data preparation:

# %%
n_media_outlets = data.shape[0]
subjects = ['Trump', 'Kamala', 'Vance', 'Walz']
n_subjects = len(subjects)

# %%
data = data.head(n = n_media_outlets).copy()
media_outlets = data['page_name'].to_list()
media_bias_label = data['media_bias'].to_list()
media_bias_value = data['bias_value'].to_list()

# %% [markdown]
# Data matrix:

# %%
mentions_matrix = np.zeros(shape = [n_media_outlets, n_subjects, 3])
for i in range(n_media_outlets):
    for j in range(n_subjects):
        mentions_matrix[i][j] = np.array(data.iloc[i][[f'{subjects[j]}_negative', f'{subjects[j]}_neutral', f'{subjects[j]}_positive']].to_list())

# %% [markdown]
# ### Inference of data

# %%
def negative_log_likelihood(x, mentions_matrix):

    """ Function to minimize """

    n_rows = mentions_matrix.shape[0]
    n_cols = mentions_matrix.shape[1]

    z, a, b = x[:n_rows], x[n_rows:(n_rows + n_cols)], x[(n_rows + n_cols):]
    
    logl = 0.00
    for i in range(n_rows):
        for j in range(n_cols):
            z_ij = z[i] * a[j] + b[j]
            N_ij = np.sum(mentions_matrix[i][j])
            logl += (mentions_matrix[i][j][2] - mentions_matrix[i][j][0]) * z_ij - N_ij * (np.log(np.exp(z_ij) + 1 + np.exp(-z_ij)))        
    
    for i in range(n_rows):
        logl -= 0.5*(z[i]**2)
    
    for j in range(n_cols):
        logl -= 0.5 *(a[j]**2 + b[j]**2)
    
    return -logl

# %%
def grad_negative_log_likelihood(x, mentions_matrix):
    
    """ Gradient of function to minimize """

    n_rows = mentions_matrix.shape[0]
    n_cols = mentions_matrix.shape[1]

    z, a, b = x[:n_rows], x[n_rows:(n_rows + n_cols)], x[(n_rows + n_cols):]
    
    grad_z = np.zeros(n_rows)
    grad_a = np.zeros(n_cols)
    grad_b = np.zeros(n_cols)
    
    for i in range(n_rows):
        for j in range(n_cols):
            z_ij = z[i] * a[j] + b[j]
            N_ij = np.sum(mentions_matrix[i][j])
            W_ij = (mentions_matrix[i][j][2] - mentions_matrix[i][j][0]) - N_ij * (np.exp(z_ij) - np.exp(-z_ij)) / (np.exp(z_ij) + 1 + np.exp(-z_ij))
            grad_z[i] += W_ij * a[j]
        grad_z[i] -= z[i]
    
    for j in range(n_cols):
        for i in range(n_rows):
            z_ij = z[i] * a[j] + b[j]
            N_ij = np.sum(mentions_matrix[i][j])
            W_ij = (mentions_matrix[i][j][2] - mentions_matrix[i][j][0]) - N_ij * (np.exp(z_ij) - np.exp(-z_ij)) / (np.exp(z_ij) + 1 + np.exp(-z_ij))
            grad_a[j] += W_ij * z[i]
            grad_b[j] += W_ij
        
        grad_a[j] -= a[j]
        grad_b[j] -= b[j]
    
    return -np.hstack([grad_z, grad_a, grad_b])

# %%
partial_negative_log_likelihood = partial(negative_log_likelihood, mentions_matrix = mentions_matrix)
partial_grad_negative_log_likelihood = partial(grad_negative_log_likelihood, mentions_matrix = mentions_matrix)

# %% [markdown]
# Optimizer:

# %%
# Bounds
lb = [-5] * (n_media_outlets + 2 * n_subjects)
ub = [5] * (n_media_outlets + 2 * n_subjects)
bounds = Bounds(lb, ub)

solution = minimize(
    fun=partial_negative_log_likelihood,
    x0=np.random.normal(size = (n_media_outlets + 2 * n_subjects)),
    method='L-BFGS-B',
    jac=partial_grad_negative_log_likelihood,
    bounds=bounds,
    tol=10**-6
)

print(solution)
# Out:
#   message: CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
#   success: True
#    status: 0
#       fun: 18526.096348368083
#         x: [ 2.395e-01  3.127e-01 ... -7.800e-01 -6.765e-01]
#       nit: 96
#       jac: [-7.314e-03 -8.915e-01 ...  1.953e-01  3.291e-01]
#      nfev: 107
#      njev: 107
#  hess_inv: <48x48 LbfgsInvHessProduct with dtype=float64>

# %%
z_predicted, a_predicted, b_predicted = solution.x[:n_media_outlets], solution.x[n_media_outlets:(n_media_outlets + n_subjects)], solution.x[(n_media_outlets + n_subjects):]

# %% [markdown]
# Data frames value predicted:

# %%
z_media_outlets = pd.DataFrame()
z_media_outlets['outlet'] = media_outlets
z_media_outlets['z'] = [z for z in z_predicted]
z_media_outlets['media_bias_label'] = media_bias_label
z_media_outlets['media_bias_value'] = media_bias_value

# %%
z_media_outlets.sort_values(by = 'z', inplace=True)

# %%
plt.figure(figsize = (8,3.5), dpi = 300)

# Normalize the values to the range [0, 1]
norm = plt.Normalize(-1, 1)

# Choose a colormap
cmap = plt.cm.bwr
color = cmap(norm(z_media_outlets['z']))

plt.bar(range(z_media_outlets.shape[0]), height=z_media_outlets['z'], color = color, linewidth = 0.75, edgecolor = 'k')
plt.xticks(range(z_media_outlets.shape[0]), z_media_outlets['outlet'], rotation = 90, size = 10)
plt.axhline(0.00, color = 'grey', linewidth = 0.75, alpha = 0.75)
plt.ylabel('z', size = 24, rotation = 0, labelpad = 2)
plt.grid(True, alpha = 0.15)
plt.yticks([-1, -0.5, 0, 0.5, 1], size = 14)
plt.ylim([-1, 1])
plt.tight_layout()
#plt.savefig('images/Media_model_score.pdf')
plt.show()

# %%
ab_subjects = pd.DataFrame()
ab_subjects['subject'] = subjects
ab_subjects['a'] = [a for a in a_predicted]
ab_subjects['b'] = b_predicted

# %%
ab_subjects.sort_values('a', inplace=True)
ab_subjects
# Out:
#   subject         a         b
# 3    Walz -1.965114 -0.676543
# 1  Kamala -1.886841 -0.531749
# 0   Trump  0.660341 -0.863246
# 2   Vance  0.676611 -0.780025

# %%
plt.figure(figsize = (3,2), dpi = 300)

plt.bar(range(ab_subjects.shape[0]), height=ab_subjects['a'], color = cmap(norm(ab_subjects['a'])), linewidth = 0.75, edgecolor = 'k')
plt.xticks(range(ab_subjects.shape[0]), ab_subjects['subject'], rotation = 90, size = 8)
plt.axhline(0.00, color = 'grey', linewidth = 0.75, alpha = 0.75)
plt.ylabel('a', size = 16, rotation = 0)
plt.grid(True, alpha = 0.15)
plt.tight_layout()
#plt.savefig('images/Candidates_coefficients.pdf')
plt.show()

# %%
plt.figure(figsize = (3,2), dpi = 300)

plt.bar(range(ab_subjects.shape[0]), height=ab_subjects['b'], color = plt.cm.gray(norm(ab_subjects['b'])), linewidth = 0.75, edgecolor = 'k')
plt.xticks(range(ab_subjects.shape[0]), ab_subjects['subject'], rotation = 90, size = 8)
plt.axhline(0.00, color = 'grey', linewidth = 0.75, alpha = 0.75)
plt.ylabel('b', size = 16, rotation = 0)
plt.grid(True, alpha = 0.15)
plt.tight_layout()
#plt.savefig('images/Candidates_biases.pdf')
plt.show()

# %% [markdown]
# ### $z_{ij}$

# %%
z_matrix = np.zeros(shape = [n_media_outlets, n_subjects])
for i in range(n_media_outlets):
    for j in range(n_subjects):
        z_matrix[i][j] = ab_subjects['a'].iloc[j] * z_media_outlets['z'].iloc[i] + ab_subjects['b'].iloc[j]

# %%
plt.figure(figsize=(5,13), dpi = 200)
plt.imshow(z_matrix, vmin=np.quantile(z_matrix.ravel(), q = 0.05), vmax=np.quantile(z_matrix.ravel(), q = 0.95), cmap='RdYlGn')
plt.yticks(range(z_media_outlets.shape[0]), z_media_outlets['outlet'])
plt.xticks(range(ab_subjects.shape[0]), ab_subjects['subject'], rotation = 90)
plt.colorbar()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Plots

# %%
z_media_outlets_without_nans = z_media_outlets.dropna()
z_media_outlets_without_nans['media_bias_label'].unique()
# Out:
# <StringArray>
# [    'far left',  'left-center', 'least biased',         'left',
#  'right-center',        'right',    'far right']
# Length: 7, dtype: str

# %%
z_media_outlets
# Out:
#                     outlet         z media_bias_label  media_bias_value
# 38           nowthisimpact -0.848256         far left              -8.5
# 6                  nytimes -0.480366      left-center              -4.1
# 13                 CBSNews -0.421070      left-center              -3.3
# 7                  ABCNews -0.405254      left-center              -3.3
# 14          washingtonpost -0.399620      left-center              -3.6
# 23                newshour -0.382825      left-center              -2.4
# 10             NBCPolitics -0.369891      left-center              -3.6
# 39                politico -0.366829      left-center              -2.8
# 9                  NBCNews -0.365078      left-center              -3.6
# 5                  TheHill -0.362311     least biased               0.4
# 34                     cnn -0.330778      left-center              -3.6
# 20             cnnpolitics -0.327206      left-center              -3.6
# 29        HuffPostPolitics -0.326380             left              -6.4
# 26       bloombergbusiness -0.324244      left-center              -2.4
# 18                Newsweek -0.297757     right-center               2.8
# 16           thedailybeast -0.246198             left              -6.6
# 32                  forbes -0.203643     least biased               1.3
# 3            NewsNationNow -0.188088     least biased               1.2
# 17              politifact -0.141724      left-center              -3.1
# 24                     TND -0.082871     right-center               2.4
# 37            ABC7Amarillo -0.055323     right-center               2.5
# 30                  snopes -0.034783      left-center              -2.8
# 19      TheWashingtonTimes  0.008584     right-center               4.2
# 25                mediaite  0.058182      left-center              -4.5
# 2       WashingtonExaminer  0.106352     right-center               3.8
# 0      ConservativeNewsDly  0.239500    extreme right               NaN
# 8                  FoxNews  0.277088            right               6.7
# 1                  NEWSMAX  0.312673            right               7.8
# 35                  theijr  0.388989            right               6.7
# 11             DailyCaller  0.419636            right               6.6
# 36     mediaresearchcenter  0.456283            right               7.1
# 22             newsbusters  0.472908            right               NaN
# 27          WesternJournal  0.534564        far right               8.0
# 12              WSJOpinion  0.563134     right-center               4.2
# 21                TheBlaze  0.642624            right               7.8
# 31       blazenewsofficial  0.693732            right               7.8
# 15              BlazeMedia  0.745583            right               7.8
# 28            RedStateBlog  0.774388            right               NaN
# 33  theconservativetribune  0.809330    extreme right               NaN
# 4                Breitbart  0.910265            right               8.1

# %%
markerdict = {'far right': '>', 'extreme right': '>', 'right': '>', 'right-center': '>', 'left-center': '<', 'least biased': 's', 'left': '<', 'far left': '<'}
colordict = {'far right': 'darkred', 'extreme right': 'darkred', 'right': 'red', 'right-center': 'lightcoral', 'left-center': 'lightblue', 'left': 'blue', 'least biased': 'gray', 'far left': 'darkblue'}

# %%
plt.figure(figsize = (5,3), dpi = 300)

for i in range(z_media_outlets_without_nans.shape[0]):
    plt.scatter(z_media_outlets_without_nans['z'].iloc[i], z_media_outlets_without_nans['media_bias_value'].iloc[i], 
            marker = markerdict[z_media_outlets_without_nans['media_bias_label'].iloc[i]], 
                color = colordict[z_media_outlets_without_nans['media_bias_label'].iloc[i]], s = 75, alpha = 0.65)
plt.xlabel('z', size = 30, labelpad = -2)
plt.xticks(size = 10)
plt.yticks(size = 12)
plt.ylabel('MB/FC bias value', size = 15)
plt.grid(True, alpha = 0.15)
plt.xlim([-1, 1])
plt.ylim([-10, 10])
plt.title("Spearman coefficient: {:.2f}".format(spearmanr(z_media_outlets_without_nans['z'], z_media_outlets_without_nans['media_bias_value']).statistic), size = 10)
plt.tight_layout()
#plt.savefig('images/Media_bias_fact_check_comparison.pdf')
plt.show()
